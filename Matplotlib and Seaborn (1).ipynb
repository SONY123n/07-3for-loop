# %%
#what is concatination ,what is merge,what is join

# %%
#matplotlib,seaborn,plotly,bokeh arre the libraries in the matplotlib and seaborn are most important libraries but plotly is used mostly bcz is more interactive

# %%
#seaborn is impotant for interview

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#plt.style.use('classic')
#http://tonysyu.github.io/raw_content/matplotlib.style.gallery.html

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
x
# Out:
# array([0.02074607, 0.10016213, 0.72397475, 0.36294658, 0.42217455,
#        0.02644348, 0.1659288 , 0.45031704, 0.62584034, 0.6609563 ,
#        0.19630707, 0.38501069, 0.63656855, 0.19174357, 0.29581815,
#        0.50074379, 0.55383796, 0.06289539, 0.98353971, 0.82833295,
#        0.82894876, 0.03063579, 0.65992331, 0.95279401, 0.9055028 ,
#        0.73472314, 0.25147546, 0.30696992, 0.85739608, 0.87805296,
#        0.00703449, 0.90838046, 0.30617628, 0.64853261, 0.61116715,
#        0.9612112 , 0.8122942 , 0.48693501, 0.45560149, 0.09629062,
#        0.1034283 , 0.94790948, 0.22310874, 0.18112979, 0.64449794,
#        0.42479721, 0.76451175, 0.51548532, 0.85723089, 0.29863257])

# %%
y
# Out:
# array([0.06962261, 0.58178338, 0.32667886, 0.71678913, 0.4162057 ,
#        0.22431054, 0.53070188, 0.83991461, 0.94470207, 0.32892053,
#        0.1570515 , 0.94556863, 0.89635172, 0.89852682, 0.71802846,
#        0.73483641, 0.23547206, 0.33434665, 0.46468022, 0.70254915,
#        0.77306539, 0.23572675, 0.71474972, 0.90290512, 0.27369465,
#        0.07907312, 0.21653086, 0.11947264, 0.07511113, 0.78664217,
#        0.92475992, 0.12260612, 0.12577474, 0.91373826, 0.6862193 ,
#        0.32609572, 0.31901072, 0.9552893 , 0.76906424, 0.43895233,
#        0.424964  , 0.29506664, 0.2274939 , 0.79116571, 0.95654413,
#        0.61078041, 0.42076058, 0.63068632, 0.83945388, 0.85221982])

# %%
plt.scatter(x,y)

# %%
d=pd.DataFrame(np.random.randn(1000),columns=['data'],index=pd.date_range('2020-04-21',periods=1000))

# %%
d
# Out:
#                 data
# 2020-04-21 -1.288705
# 2020-04-22 -0.355492
# 2020-04-23  0.865726
# 2020-04-24 -1.514942
# 2020-04-25 -2.286887
# ...              ...
# 2023-01-11  0.473892
# 2023-01-12  0.191881
# 2023-01-13 -1.014616
# 2023-01-14 -0.628837
# 2023-01-15 -0.995590
#
# [1000 rows x 1 columns]

# %%
d.plot(figsize=(20,8))
# Out:
# <Axes: >

# %%
x=np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x)

# %%
plt.plot(x,np.sin(x))

# %%
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.tan(x))

# %%
plt.plot(x,np.sec(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 plt.plot(x,np.sec(x))
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'sec'

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.plot(x,np.tan(x))

# %%
plt.plot(x,np.sin(x),'-')

# %%
plt.plot(x,np.sin(x),'- -')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 plt.plot(x,np.sin(x),'- -')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
# ...

# %%
plt.plot(x,np.sin(x),'- -')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 plt.plot(x,np.sin(x),'- -')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
# ...

# %%
plt.plot(x,np.sin(x),'.-')

# %%
plt.plot(x,np.sin(x),'s')

# %%
plt.plot(x,np.sin(x),'O')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 plt.plot(x,np.sin(x),'O')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
# ...

# %%
plt.plot(x,np.sin(x),':')

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))


plt.subplot(1,2,2)
plt.plot(x,np.cos(x))
plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))


plt.subplot(2,2,2)
plt.plot(x,np.cos(x))
plt.show()

plt.subplot(2,2,3)
plt.plot(x,np.tan(x))


plt.subplot(2,2,4)
plt.plot(x,np.cos(x+1))

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))


plt.subplot(2,1,2)
plt.plot(x,np.cos(x))
plt.show()

# %%
plt.plot(x,np.sin(x-0),color='orange')
plt.plot(x,np.sin(x-1),color='green')
plt.plot(x,np.sin(x*2),color='blue')

# %%
plt.plot(x,np.sin(x-0),color='r')
plt.plot(x,np.sin(x-1),color='g')
plt.plot(x,np.sin(x-2),color=(1.0,0.5,0))#rgb color

# %%
plt.plot(x,np.sin(x-0),color='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
# Out:
# (1.0, 15.0)

# %%
plt.plot(x,np.sin(x-0),color='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.0993384025373631, 1.0996461858110391)

# %%
plt.plot(x,np.sin(x-0),color='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid()
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.0993384025373631, 1.0996461858110391)

# %%
plt.plot(x,np.sin(x-0),color='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid()
plt.axis('equal')
plt.title('this is sin plot before real dataset execution to understand basic syntax')
# Out:
# Text(0.5, 1.0, 'this is sin plot before real dataset execution to understand basic syntax')

# %%
plt.plot(x,np.sin(x-0),color='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid()
plt.axis('equal')
plt.title('this is sin plot before real dataset execution to understand basic syntax')
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.plot(x,np.sin(x-0),color='b',label='sinx')
plt.plot(x,np.cos(x-0),color='r',label='cosx')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid()
#plt.axis('equal')
plt.title('this is sin plot before real dataset execution to understand basic syntax')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()

# %%
#histogram
data=np.random.randn(1000)

# %%
data
# Out:
# array([ 5.52597388e-01,  4.08617101e-01,  9.48653903e-01,  5.44801448e-01,
#        -2.42236600e+00,  2.43404064e+00,  1.98983817e+00, -1.10046142e+00,
#        -1.69640641e+00,  1.07215840e+00,  1.15323638e+00, -1.68611919e+00,
#         1.51475282e+00, -1.09328243e+00, -9.29625777e-01,  1.30095041e+00,
#        -1.40490494e+00, -1.06960076e+00, -9.34842488e-01, -4.09318071e-01,
#        -8.26269604e-01, -6.99286539e-01, -4.05125703e-01,  1.45634089e+00,
#        -7.22784505e-01,  7.84568104e-01, -2.95413449e-01, -7.08004072e-01,
#        -8.28664627e-01,  2.84503679e-01, -1.81351426e+00, -2.16263925e+00,
#        -1.25985246e+00, -3.98674894e-01, -2.10754849e-01, -3.17081427e-01,
#        -1.32304089e+00,  1.35317654e+00,  2.16332963e+00,  1.68927852e+00,
#         2.16900617e+00,  1.40333839e+00, -8.43326694e-01, -6.82520255e-01,
#         5.42142603e-01,  2.71770809e-01,  4.23592069e-01, -2.04573274e+00,
# ...

# %% [raw]
# #for continuous data u will make histogram or distribution plot
# #but to know the data frequency histogram is made
# #for chatagorical data we can make bar plot (for the clear visivalisation)
# #the above is a continuous data
# #for discrete it is bar plot

# %%
plt.hist(data,bins=20,histtype='bar',color='pink')#histogram
plt.show()

# %%
plt.hist(data,bins=20,histtype='step',color='pink')#histogram
plt.show()

# %%
#bin-the smallest unit in which ur dividing the data
#there will be by default 10 bins created
#

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y
# Out:
# array([0.06962261, 0.58178338, 0.32667886, 0.71678913, 0.4162057 ,
#        0.22431054, 0.53070188, 0.83991461, 0.94470207, 0.32892053,
#        0.1570515 , 0.94556863, 0.89635172, 0.89852682, 0.71802846,
#        0.73483641, 0.23547206, 0.33434665, 0.46468022, 0.70254915,
#        0.77306539, 0.23572675, 0.71474972, 0.90290512, 0.27369465,
#        0.07907312, 0.21653086, 0.11947264, 0.07511113, 0.78664217,
#        0.92475992, 0.12260612, 0.12577474, 0.91373826, 0.6862193 ,
#        0.32609572, 0.31901072, 0.9552893 , 0.76906424, 0.43895233,
#        0.424964  , 0.29506664, 0.2274939 , 0.79116571, 0.95654413,
#        0.61078041, 0.42076058, 0.63068632, 0.83945388, 0.85221982])

# %%
x=np.random.rand(50)
y=np.random.rand(50)

plt.figure(figsize=(6,2))
plt.scatter(x,y,c='m',alpha=.5,marker="*")#alpha is nothing t=but it is value to control the intensity of the colr
plt.xlabel('x')
plt.ylabel('y')
plt.title('scatter plot')
plt.show()

# %%
#why do we making this scatter plot

# %%
x=["a","b","c","d"]#x is a chatagirical data
#y=np.random.rand(5)
y=[3,2,4,6]#this is the count data

# %%
x
# Out:
# ['a', 'b', 'c', 'd']

# %%
y
# Out:
# [3, 2, 4, 6]

# %%
plt.figure(figsize=(6,3))
plt.bar(x,y,color='k')
plt.title("this is my bar plot")
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.figure(figsize=(6,3))
plt.barh(x,y,color='m')#barh means it will take the x axis values to y and y to x
plt.title("this is my bar plot")
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
#in industry only blue color is used

# %%
data=[1,2,3,]
plt.hist(data)
plt.show()

# %%
#3D plot

# %%
x=np.random.rand(20)
y=np.random.rand(20)
z=np.random.rand(20)
fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter(x,y,z,color='m',alpha=.75)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
import os
os.path.exists(r"C:\Users\jarup\Downloads\Bank_churn.csv")
# Out:
# True

# %%
data=pd.read_csv(r"C:\Users\jarup\Downloads\Bank_churn.csv")

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.plot.scatter(x='Age',y='Balance')
#insigths
#where is maximum concetration>>25_50
#max balance >>40
#min>=0,it is present in all age group
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
#age distribution
plt.title("age distribution")
plt.hist(data['Age'],color='m',alpha=.676)
plt.show()

plt.title("balance distribution")
plt.hist(data['Balance'],color='g',alpha=.676)
plt.show()

# %%
#pie chart

langs=['c','python','java']
students=[20,100,40]

plt.pie(students,labels=langs,autopct='%1.1f%%')#autopct is used to level up the visvalisation
plt.title("pie chart")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
my_explod=(0.0,0.1,0.1)

langs=['c','python','java']
students=[20,100,40]

plt.pie(students,labels=langs,autopct='%1.1f%%',explode=my_explod,shadow=True)#autopct is used to level up the visvalisation
plt.title("pie chart")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.boxplot(column='Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x23cb134b830>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x23cb13b7fe0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x23cb12fdb50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x23cb134b1a0>}

# %%
#SEABORN
#y seaborn - seaborn will gives u better insight
#seabron is more widly used than the matplotlib

# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.histplot(tips['total_bill'])
#in seaborn it is most updated visivalization that's the reason we are seeing the dark lines
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips['total_bill'])#this the distribution plot
#the line is showing is called kernal density estimetor
# Out:
# C:\Users\jarup\AppData\Local\Temp\ipykernel_21056\3897755372.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])#this the distribution plot
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)
# Out:
# C:\Users\jarup\AppData\Local\Temp\ipykernel_21056\1274391954.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],kde=False,bins=30)
# <Axes: xlabel='total_bill'>

# %%
sns.scatterplot(tips['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(x=tips.total_bill,y=tips.tip,color='g')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips,hue='smoker',color='brown')
#hue is a parameter which will differentiate the data

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips,hue='size')

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips,style='size')
#style is a pattern which will differentiate the data

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips,style='smoker',hue='time',color='brown')

# %%
sns.catplot(x='day',y='total_bill',data=tips)#catplot means the chagorical plot

# %%
sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x=tips.total_bill,y=tips.tip)

# %%
sns.jointplot(x=tips.total_bill,y=tips.tip,data=tips,kind='reg')
#reg means regration line

# %%
sns.jointplot(x=tips.total_bill,y=tips.tip,data=tips,kind='hex')

# %%
sns.jointplot(x=tips.total_bill,y=tips.tip,data=tips,kind='kde')
#countour to be used in meterlogical

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips,hue='smoker')

# %%
sns.pairplot(tips,hue='time')

# %%
sns.pairplot(tips,hue='day')

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')
#https://seaborn.pydata.org/generated/seaborn.color_palette.html
#https://seaborn.pydata.org/tutorial/color_paletters.html

# %%
#boxplot>> to know outliers
#1,2,3,4,5,10000>>>>extreme data are outliers
sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')
# Out:
# C:\Users\jarup\AppData\Local\Temp\ipykernel_21056\2990295047.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %%
#correlation>>to understand the relationship bwill only create with numerical data only

# %%
tips_num=tips[['total_bill','tip','size']]

# %%
tips_num
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
tips_num.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips_num.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,height=4,aspect=4)#barplot and count plot are same

# %%
sns.catplot(x='day',y='tip',data=tips,kind='swarm')
# Out:
# C:\Users\jarup\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
