# %%
#seaborn library has many plots
#1) boxplot:This is used to determine the outlier
#2)scatterplot: this is used to umderstand relationship between two variables/two data sets
#3)barplot:this is used for the categorical data
#4)lineplot: this is used to represent the data whenever on x-axis ,we have time ccomponents
#5)-pieplot:this is used for the distribution of different unique classe

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sos=sns.load_dataset('fmri')
sos
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x='timepoint',y='signal',data=sos)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
tit=sns.load_dataset('titanic')
tit
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(x='pclass', y='age', data=tit, palette='pastel', notch=True)
plt.title('Age Distribution by Class with Notches')
plt.show()


sns.boxplot(x='class', y='fare', data=tit, palette='pastel', notch=True)
plt.title('Age Distribution by Class with Notches')
plt.show()
# Out:
# C:\Users\jarup\AppData\Local\Temp\ipykernel_14596\3123816593.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='pclass', y='age', data=tit, palette='pastel', notch=True)
# C:\Users\jarup\AppData\Local\Temp\ipykernel_14596\3123816593.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='fare', data=tit, palette='pastel', notch=True)

# %%
dia=sns.load_dataset('diamonds')
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.histplot(x='price',hue='cut',data=dia)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Diamond Prices by Cut')
plt.show()

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris,hue='species',palette='pastel')

# %%
flights=sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.heatmap(flights, annot=True, fmt=".0f", cmap="orange")
plt.title("Monthly Passenger Counts by Year")
plt.xlabel("Year")
plt.ylabel("Month")
plt.show()
import pandas as pd

data = pd.DataFrame({'values': ['1.2', '2.3', 'Jan']})
data['values'] = pd.to_numeric(data['values'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 sns.heatmap(flights, annot=True, fmt=".0f", cmap="orange")
#       2 plt.title("Monthly Passenger Counts by Year")
#       3 plt.xlabel("Year")
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %%
flights.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
flights.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

flights = sns.load_dataset("flights")

# Convert 'month' column to numerical representation
flights['month'] = pd.Categorical(flights['month']).codes + 1  # +1 to avoid 0
flights_pivot = flights.pivot(index="month", columns="year", values="passengers") 

sns.heatmap(flights_pivot, annot=True, fmt=".0f", cmap="Oranges")
plt.title("Monthly Passenger Counts by Year")
plt.xlabel("Year")
plt.ylabel("Month")
plt.show()
